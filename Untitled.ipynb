# %%
from utils import unzip_with_7z

zip_file_path = 'congrats.7z'  # keep as is
dest_path = '.'  # keep as is

find_me = ''  # 2 letters are missing!
secret_password = find_me + 'bcmpda' 

# WRITE YOUR CODE BELOW

def crack_pass_list():
    letters = 'qwertyuiopasdfghjklzxcvbnm'
    sp_letters = [a + b for a in letters for b in letters]
    return sp_letters
sp_letters = crack_pass_list()
sp_letters
for i in sp_letters:
    find_me = i
    secret_password = find_me + 'bcmpda'
    if unzip_with_7z(zip_file_path,dest_path,secret_password):
        print("Archive successfully unpacked with password:",secret_password)
        break  # Выходим из цикла, если распаковка прошла успешно
    else:
        print(f"Password {secret_password} does not match. Trying the next one.")
# Out:
# Password qqbcmpda does not match. Trying the next one.
# Password qwbcmpda does not match. Trying the next one.
# Password qebcmpda does not match. Trying the next one.
# Password qrbcmpda does not match. Trying the next one.
# Password qtbcmpda does not match. Trying the next one.
# Password qybcmpda does not match. Trying the next one.
# Password qubcmpda does not match. Trying the next one.
# Password qibcmpda does not match. Trying the next one.
# Password qobcmpda does not match. Trying the next one.
# Password qpbcmpda does not match. Trying the next one.
# Password qabcmpda does not match. Trying the next one.
# Password qsbcmpda does not match. Trying the next one.
# Password qdbcmpda does not match. Trying the next one.
# Password qfbcmpda does not match. Trying the next one.
# Password qgbcmpda does not match. Trying the next one.
# Password qhbcmpda does not match. Trying the next one.
# Password qjbcmpda does not match. Trying the next one.
# ...
